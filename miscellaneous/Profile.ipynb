# %% [markdown]
# # Profile
# https://stackoverflow.com/questions/8283112/cprofile-saving-data-to-file-causes-jumbles-of-characters

# %%
import pstats

# %%
p = pstats.Stats('../data/profile')
p.sort_stats('cumtime').print_stats()
# Out:
# Thu Oct 26 01:21:34 2017    ../data/profile
#
#          184028058 function calls (184004650 primitive calls) in 340.805 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#     248/1    0.011    0.000  340.805  340.805 {built-in method builtins.exec}
#         1   20.049   20.049  340.805  340.805 extract_lex.py:1(<module>)
#     40918    0.597    0.000  214.360    0.005 /Users/willian/Github/Willian-Zhang/inverted-index/.env/lib/python3.6/site-packages/langid/langid.py:290(classify)
#     40918  162.143    0.004  171.334    0.004 /Users/willian/Github/Willian-Zhang/inverted-index/.env/lib/python3.6/site-packages/langid/langid.py:252(instance2fv)
#      1952    2.513    0.001   63.177    0.032 extract_lex.py:74(<listcomp>)
#   3992919    3.392    0.000   57.432    0.000 /Users/willian/Github/Willian-Zhang/inverted-index/.env/lib/python3.6/site-packages/jieba/__init__.py:272(cut)
# ...
